# %%
from main_package.Stock_main import *
from main_package.Buy import *
from sub_package.User import *
from sub_package.bot import *
from sub_package.endgame import *

#Create two objects, first for user and the second for Dobby
#Process processes inputs and game attributes
Stock1 = Stock()
U1 = User(Stock1)
U1.process()

U2 = bot(Stock1)
U2.process()

#This extracts output result attributes from the game into status for end game totals and results
player_1_status = [U1.get_expense_list(), U1.get_price_of_stock_buy_list(), U1.get_volume()]
dobby_2_status = [U2.get_expense_list(), U2.get_price_of_stock_buy_list(), U2.get_volume()]
stock_list = [Stock1.get_high_price(), Stock1.get_low_price(), Stock1.get_size()]
# print(player_1_status, '\n', dobby_2_status, '\n', stock_list)

### Execute end game ###

# Add cashback amount to totals
(cb1, cb2) = cashback(player_1_status, dobby_2_status)
dobby_2_status.append(cb2)
player_1_status.append(cb1)
#Final value
dobby_final_value = final_price(dobby_2_status, stock_list)
dobby_2_status.append(dobby_final_value)
# print(dobby_final_value)
player_final_value = final_price(player_1_status, stock_list)
player_1_status.append(player_final_value)

# create a dataframe for player 1

headers = ['Totalexpense','Buyprice','Buyvol','Cashback','Sellprice']
pd1 = pd.DataFrame(player_1_status, headers)
pd1.index.name = 'Round'
pd1 = pd1.T
pd1['Sellvalue'] = pd1.Buyvol * pd1.Sellprice
pd1['GainLoss'] = pd1.Sellvalue + pd1.Cashback - pd1.Totalexpense
pd1.index = np.arange(1, len(pd1) + 1) # set index of dataframe sarting from 1
pd1.loc['Column_Total']= pd1.sum(numeric_only=True, axis=0)



# create a dataframe for player 2
headers = ['Totalexpense','Buyprice','Buyvol','Cashback','Sellprice']
pd2 = pd.DataFrame(dobby_2_status, headers)
pd2.index.name = 'Round'
pd2 = pd2.T

pd2['Sellvalue'] = pd2.Buyvol * pd2.Sellprice
pd2['GainLoss'] = pd2.Sellvalue + pd2.Cashback - pd2.Totalexpense
pd2.index = np.arange(1, len(pd2) + 1) # set index of dataframe sarting from 1
pd2.loc['Column_Total']= pd2.sum(numeric_only=True, axis=0)



# print the final result
print("\n------Final Result------\n")
print("Player")
print(pd1)
print("\nDobby")
print(pd2)


player_score = pd1.loc['Column_Total']['GainLoss']
dobby_score = pd2.loc['Column_Total']['GainLoss']
if dobby_score > player_score:
      print("The winner is: DOBBY!!!")
else:
      print("The winner is: YOU!!!")
# Out:
# How many round do you want to play with?6
# You are going to play 6 round, get ready!!!!!!!!
#
#
# |----------------Round1-----------------|
# |The high price of stock is 345 	|
# |The low price of stock is 180 		|
# |The volume of stock is 132 		|
# Do you want to buy the stock? (Y/N)
# Y
# |	-------- Buying --------	|
# |Enough balance to buy the stock	|
# |The random price of stock: 242.0	|
# |Volume of stock is 132			|
# How many volume do you want to buy?
# 10
# |You bought 10.0 volume of stock  	|
# |Input vol: 10.0, expense: 2420.0 	|
# |---------------------------------------|
#
# |----------------Round2-----------------|
# |The high price of stock is 445 	|
# |The low price of stock is 84 		|
# |The volume of stock is 121 		|
# Do you want to buy the stock? (Y/N)
# Y
# |	-------- Buying --------	|
# |Enough balance to buy the stock	|
# |The random price of stock: 424.0	|
# |Volume of stock is 121			|
# How many volume do you want to buy?
# 0
# |You bought 0.0 volume of stock  	|
# |Input vol: 0.0, expense: 0.0 	|
# |---------------------------------------|
#
# |----------------Round3-----------------|
# |The high price of stock is 364 	|
# |The low price of stock is 164 		|
# |The volume of stock is 107 		|
# Do you want to buy the stock? (Y/N)
# Y
# |	-------- Buying --------	|
# |Enough balance to buy the stock	|
# |The random price of stock: 346.0	|
# |Volume of stock is 107			|
# How many volume do you want to buy?
# 0
# |You bought 0.0 volume of stock  	|
# |Input vol: 0.0, expense: 0.0 	|
# |---------------------------------------|
#
# |----------------Round4-----------------|
# |The high price of stock is 456 	|
# |The low price of stock is 167 		|
# |The volume of stock is 63 		|
# Do you want to buy the stock? (Y/N)
# Y
# |	-------- Buying --------	|
# |Enough balance to buy the stock	|
# |The random price of stock: 368.0	|
# |Volume of stock is 63			|
# How many volume do you want to buy?
# 0
# |You bought 0.0 volume of stock  	|
# |Input vol: 0.0, expense: 0.0 	|
# |---------------------------------------|
#
# |----------------Round5-----------------|
# |The high price of stock is 390 	|
# |The low price of stock is 193 		|
# |The volume of stock is 121 		|
# Do you want to buy the stock? (Y/N)
# Y
# |	-------- Buying --------	|
# |Enough balance to buy the stock	|
# |The random price of stock: 206.0	|
# |Volume of stock is 121			|
# How many volume do you want to buy?
# 20
# |You bought 20.0 volume of stock  	|
# |Input vol: 20.0, expense: 4120.0 	|
# |---------------------------------------|
#
# |----------------Round6-----------------|
# |The high price of stock is 348 	|
# |The low price of stock is 140 		|
# |The volume of stock is 146 		|
# Do you want to buy the stock? (Y/N)
# Y
# |	-------- Buying --------	|
# |Enough balance to buy the stock	|
# |The random price of stock: 330.0	|
# |Volume of stock is 146			|
# How many volume do you want to buy?
# 0
# |You bought 0.0 volume of stock  	|
# |Input vol: 0.0, expense: 0.0 	|
# |---------------------------------------|
#
# End of the game
# ----------------------------------------
# Calculating your total expense.........
#
# Dobby's turn to play
#
# |----------------Round1-----------------|
# |The high price of stock is 345 	|
# |The low price of stock is 180 		|
# |The volume of stock is 132 		|
# |***Dobby is buying***
# |	-----Dobby Buying ----- 	|
# |The random price of stock: 278.0	|
# |Maximum volume of stock is 35.0 	|
# |Enough balance to buy the stock	|
# |---------------------------------------|
# |Dobby bought 26 volume of stock  	|
# |Input vol: 26, expense: 7228 		|
#
# |----------------Round2-----------------|
# |The high price of stock is 445 	|
# |The low price of stock is 84 		|
# |The volume of stock is 121 		|
# |***Dobby is buying***
# |	-----Dobby Buying ----- 	|
# |The random price of stock: 411.0	|
# |Maximum volume of stock is 6.0 	|
# |Enough balance to buy the stock	|
# |---------------------------------------|
# |Dobby bought 5 volume of stock  	|
# |Input vol: 5, expense: 2055 		|
#
# |----------------Round3-----------------|
# |The high price of stock is 364 	|
# |The low price of stock is 164 		|
# |The volume of stock is 107 		|
# |***Dobby is buying***
# |	-----Dobby Buying ----- 	|
# |The random price of stock: 181.0	|
# |Maximum volume of stock is 3.0 	|
# |Enough balance to buy the stock	|
# |---------------------------------------|
# |Dobby bought 1 volume of stock  	|
# |Input vol: 1, expense: 181 		|
#
# |----------------Round4-----------------|
# |The high price of stock is 456 	|
# |The low price of stock is 167 		|
# |The volume of stock is 63 		|
# |***Dobby pass this round*** 		|
# |---------------------------------------|
#
# |----------------Round5-----------------|
# |The high price of stock is 390 	|
# |The low price of stock is 193 		|
# |The volume of stock is 121 		|
# |***Dobby is buying***
# |	-----Dobby Buying ----- 	|
# |The random price of stock: 331.0	|
# |Maximum volume of stock is 1.0 	|
# |Enough balance to buy the stock	|
# |---------------------------------------|
# |Dobby bought 1 volume of stock  	|
# |Input vol: 1, expense: 331 		|
#
# |----------------Round6-----------------|
# |The high price of stock is 348 	|
# |The low price of stock is 140 		|
# |The volume of stock is 146 		|
# |***Dobby is buying***
# |	-----Dobby Buying ----- 	|
# |The random price of stock: 307.0	|
# |Maximum volume of stock is 0.0 	|
# Not enough balance for this stock, so Dobby pass this round
# |---------------------------------------|
#
# End of the game
# ----------------------------------------
# Calculating your total expense.........
# The total price of the stock you bought is 9795.0
#
# ------Final Result------
#
# Player
# Round         Totalexpense  Buyprice  Buyvol  Cashback  Sellprice  Sellvalue  \
# 1                   2420.0     242.0    10.0       0.0      317.0     3170.0
# 2                      0.0     424.0     0.0    2055.0      277.0        0.0
# 3                      0.0     346.0     0.0     181.0      189.0        0.0
# 4                      0.0     368.0     0.0       0.0      290.0        0.0
# 5                   4120.0     206.0    20.0       0.0      326.0     6520.0
# 6                      0.0     330.0     0.0       0.0      323.0        0.0
# Column_Total        6540.0    1916.0    30.0    2236.0     1722.0     9690.0
#
# Round         GainLoss
# 1                750.0
# 2               2055.0
# 3                181.0
# 4                  0.0
# 5               2400.0
# 6                  0.0
# Column_Total    5386.0
#
# Dobby
# Round         Totalexpense  Buyprice  Buyvol  Cashback  Sellprice  Sellvalue  \
# 1                   7228.0     278.0    26.0       0.0      246.0     6396.0
# 2                   2055.0     411.0     5.0       0.0      316.0     1580.0
# 3                    181.0     181.0     1.0       0.0      166.0      166.0
# 4                      0.0       0.0     0.0       0.0      309.0        0.0
# 5                    331.0     331.0     1.0       0.0      315.0      315.0
# 6                      0.0       0.0     0.0       0.0      186.0        0.0
# Column_Total        9795.0    1201.0    33.0       0.0     1538.0     8457.0
#
# Round         GainLoss
# 1               -832.0
# 2               -475.0
# 3                -15.0
# 4                  0.0
# 5                -16.0
# 6                  0.0
# Column_Total   -1338.0
# The winner is: YOU!!!
